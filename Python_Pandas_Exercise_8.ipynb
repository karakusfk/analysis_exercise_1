# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/content/googleplaystore.csv")

# %% [markdown]
# General Information About the Dataset

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %%
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# total number of app titles contains Astrology

# %%
df.columns #first i needed to look at columns again
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#total number of app titles contains Astrology
sum(df["App"].str.contains("Astrology",case=False))
# Out:
# 3

# %% [markdown]
# average app ratings

# %%
#average app rating
df["Rating"].mean()
# Out:
# 4.193338315362443

# %% [markdown]
# Applications that belong to PHOTOGRAPHY Category

# %%
df["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df[df["Category"] == "PHOTOGRAPHY"].sort_values(by="Rating", ascending=False)
# Out:
#                                  App     Category  Rating Reviews  Size  \
# 5238   Selfie With Champion AJ Style  PHOTOGRAPHY     5.0       2  7.5M
# 7127                 CB VIDEO VISION  PHOTOGRAPHY     5.0      13  2.6M
# 9178                         i am EB  PHOTOGRAPHY     5.0       1  5.4M
# 5230                          AJ Cam  PHOTOGRAPHY     5.0      44  2.8M
# 8281                          DC-014  PHOTOGRAPHY     5.0       3   16M
# ...                              ...          ...     ...     ...   ...
# 8939              DV-4036 by Somikon  PHOTOGRAPHY     NaN      17   44M
# 8941                        Touch DV  PHOTOGRAPHY     NaN       1   11M
# 9083               Displaying You VR  PHOTOGRAPHY     NaN       1   67M
# 9294               EF Lens Simulator  PHOTOGRAPHY     NaN       2   33M
# 10311                  FD Fotografia  PHOTOGRAPHY     NaN       2  4.2M
#
#       Installs  Type  Price Content Rating       Genres        Last Updated  \
# ...

# %%
df[df["Category"] == "PHOTOGRAPHY"].mean()
# Out:
# <ipython-input-23-303c31d850e1>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["Category"] == "PHOTOGRAPHY"].mean()
# Rating     4.192114
# Reviews         inf
# dtype: float64

# %%
df[df["Category"] == "SOCIAL"].mean()
# Out:
# <ipython-input-24-bca1f2430e48>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["Category"] == "SOCIAL"].mean()
# Rating     4.255598
# Reviews         inf
# dtype: float64

# %%
#which category has highest rank?
df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
#total apps having 5 stars
sum(df["Rating"] == 5)
# Out:
# 274

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Average value of the reviews

# %%
#find average value of reviews
#first we need to convert the datatype of "Reviews" column from object to float64
df["Reviews"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-f24c481abb10> in <module>
#       1 #find average value of reviews
#       2 #first we need to convert the datatype of "Reviews" column from object to float64
# ----> 3 df["Reviews"].astype("float")
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
#ValueError: could not convert string to float: '3.0M'
#first we need to remove '3.0M'. because of that value we cannot change the dtype
df[df["Reviews"]=="3.0M"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df["Reviews"] = df["Reviews"].replace("3.0M",3.0) #with replace method we have changed the value into float and erased 'M' letter.

# %%
df["Reviews"].astype("float") #cconvert the column into float from object
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
df["Reviews"] = df["Reviews"].astype("float").sort_values(ascending=False)

# %%
df["Reviews"].mean()
# Out:
# 444111.9265750392

# %%
sum(df["Reviews"].between(10000000,20000000))
# Out:
# 55

# %%
data1 = df[df["Reviews"].between(10000000,20000000)][["App","Rating"]].sort_values(by="Rating",ascending=False)

# %%
data1
# Out:
#                                                     App  Rating
# 1932                                     Shadow Fight 2     4.6
# 7937                                     Shadow Fight 2     4.6
# 4568    360 Security - Free Antivirus, Booster, Cleaner     4.6
# 2090           Minion Rush: Despicable Me Official Game     4.5
# 3239  Cache Cleaner-DU Speed Booster (booster & clea...     4.5
# 1970                                        8 Ball Pool     4.5
# 2050           Minion Rush: Despicable Me Official Game     4.5
# 378         UC Browser - Fast Download Private & Secure     4.5
# 2808                                      Google Photos     4.5
# 2853                                      Google Photos     4.5
# 2884                                      Google Photos     4.5
# 3888                                     My Talking Tom     4.5
# 1893                                            Yes day     4.5
# 3953                                        8 Ball Pool     4.5
# ...

# %%
df.drop_duplicates(subset=["App"],inplace=True)

# %%
data1.drop_duplicates(subset=["App"],inplace=True)

# %%
data1
# Out:
#                                                     App  Rating
# 1932                                     Shadow Fight 2     4.6
# 4568    360 Security - Free Antivirus, Booster, Cleaner     4.6
# 2090           Minion Rush: Despicable Me Official Game     4.5
# 3239  Cache Cleaner-DU Speed Booster (booster & clea...     4.5
# 1970                                        8 Ball Pool     4.5
# 378         UC Browser - Fast Download Private & Secure     4.5
# 2808                                      Google Photos     4.5
# 3888                                     My Talking Tom     4.5
# 1893                                            Yes day     4.5
# 3975                                            Hay Day     4.5
# 8896  DU Battery Saver - Battery Charger & Battery Life     4.5
# 1885                                                Pou     4.3
# 385                                     Viber Messenger     4.3
# 6449                        BBM - Free Calls & Messages     4.3
# ...

# %%
df[df["Reviews"] > 40000000].sort_values(by="Rating",ascending=False)
# Out:
#                                            App       Category  Rating  \
# 4005   Clean Master- Space Cleaner & Antivirus          TOOLS     4.7
# 1670                            Clash of Clans           GAME     4.6
# 2545                                 Instagram         SOCIAL     4.5
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 2544                                  Facebook         SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
#
#          Reviews                Size        Installs  Type Price  \
# 4005  42916526.0  Varies with device    500,000,000+  Free     0
# 1670  44891723.0                 98M    100,000,000+  Free     0
# 2545  66577313.0  Varies with device  1,000,000,000+  Free     0
# 336   69119316.0  Varies with device  1,000,000,000+  Free     0
# 2544  78158306.0  Varies with device  1,000,000,000+  Free     0
# 335   56642847.0  Varies with device  1,000,000,000+  Free     0
#
# ...

# %%
df["Genres"].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
data2 = df[(df["Rating"].between(4.0,5.0)) & (df["Reviews"] > 10000000)][["App","Genres","Rating","Reviews"]]

# %%
data2.groupby("Genres")["Rating"].mean()
# Out:
# Genres
# Action                       4.600000
# Adventure                    4.100000
# Arcade                       4.500000
# Casual                       4.440000
# Casual;Action & Adventure    4.500000
# Communication                4.257143
# News & Magazines             4.300000
# Photography                  4.500000
# Social                       4.200000
# Sports                       4.500000
# Strategy                     4.600000
# Tools                        4.600000
# Video Players & Editors      4.300000
# Name: Rating, dtype: float64

# %%
len(data2)
# Out:
# 30

# %%
data2 = data2.drop("Reviews",axis=1)

# %%
data2.head(30)
# Out:
#                                                     App  \
# 335            Messenger – Text and Video Chat for Free
# 336                                  WhatsApp Messenger
# 342                                     Viber Messenger
# 378         UC Browser - Fast Download Private & Secure
# 391                       Skype - free IM & video calls
# 403                         LINE: Free Calls & Messages
# 406                         BBM - Free Calls & Messages
# 1654                                     Subway Surfers
# 1655                                   Candy Crush Saga
# 1660                                       Clash Royale
# 1662                                                Pou
# 1670                                     Clash of Clans
# 1675                                        8 Ball Pool
# 1694           Minion Rush: Despicable Me Official Game
# 1722                                     My Talking Tom
# 1764                                         Pokémon GO
# ...

# %%
data3 = data2.groupby(["Genres"]).mean().sort_values(by="Rating",ascending=False)
data3.head()
# Out:
#                            Rating  Number of App
# Genres
# Action                        4.6            NaN
# Strategy                      4.6            NaN
# Tools                         4.6            NaN
# Arcade                        4.5            NaN
# Casual;Action & Adventure     4.5            NaN

# %%
data3["Number of App"] = data2.groupby(["Genres"])["Genres"].count()

# %%
data3.head()
# Out:
#                            Rating  Number of App
# Genres
# Action                        4.6              1
# Strategy                      4.6              2
# Tools                         4.6              5
# Arcade                        4.5              1
# Casual;Action & Adventure     4.5              1

# %%
data3.columns
# Out:
# Index(['Rating', 'Number of App'], dtype='object')

# %%
data3.columns = ["Avg Rating", "Number of App"]

# %%
data3
# Out:
#                            Avg Rating  Number of App
# Genres
# Action                       4.600000              1
# Strategy                     4.600000              2
# Tools                        4.600000              5
# Arcade                       4.500000              1
# Casual;Action & Adventure    4.500000              1
# Photography                  4.500000              1
# Sports                       4.500000              1
# Casual                       4.440000              5
# News & Magazines             4.300000              1
# Video Players & Editors      4.300000              1
# Communication                4.257143              7
# Social                       4.200000              3
# Adventure                    4.100000              1

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, Action to Adventure
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Avg Rating     13 non-null     float64
#  1   Number of App  13 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 868.0+ bytes

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Type"].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9660 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         9660 non-null   float64
#  4   Size            9660 non-null   object
#  5   Installs        9660 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9660 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9660 non-null   object
#  10  Last Updated    9660 non-null   object
#  11  Current Ver     9652 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
df[df["Type"].isnull()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN      0.0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df["Type"] = df["Type"].dropna(how="any",axis=0)

# %%
#find total number of free and paid apps
print("Free Apps:",len(df[df["Type"] == "Free"]))
print("Paid Apps:",len(df[df["Type"] == "Paid"]))
# Out:
# Free Apps: 8902
# Paid Apps: 756

# %%
#which app has maximum reviews
df[df["Reviews"].max() == df["Reviews"]][["App","Reviews","Rating"]]
# Out:
#            App     Reviews  Rating
# 2544  Facebook  78158306.0     4.1

# %%
#display top 5 apps have maximum installs
df["Installs"].dtype
# Out:
# dtype('O')

# %%
df["Installs"] = df["Installs"].str.replace(",","")

# %%
df["Installs"]
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs, Length: 9660, dtype: object

# %%
df["Installs"] = df["Installs"].str.replace("+","")
# Out:
# <ipython-input-157-7872ae33284b>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Installs"] = df["Installs"].str.replace("+","")

# %%
df["Installs"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9660, dtype: object

# %%
df["Installs"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-f2c2eb4e9c23> in <module>
# ----> 1 df["Installs"].astype("int")
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
df[df["Installs"] == "Free"]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      3.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df["Installs"] = df["Installs"].str.replace("Free","0")

# %%
sum(df["Installs"] == "Free")
# Out:
# 0

# %%
df["Installs"]=df["Installs"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9660 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         9660 non-null   float64
#  4   Size            9660 non-null   object
#  5   Installs        9660 non-null   int64
#  6   Type            9659 non-null   object
#  7   Price           9660 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9660 non-null   object
#  10  Last Updated    9660 non-null   object
#  11  Current Ver     9652 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
df[df["Installs"].sort_values(ascending=False).head()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-187-ded46e014d2a> in <module>
# ----> 1 df[df["Installs"].sort_values(ascending=False).head()]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %%
sorted_df = df.sort_values(by="Installs",ascending=False).head()[["App","Installs","Rating"]]

# %%
sorted_df.sort_values(by="Rating",ascending=False).head()
# Out:
#                             App    Installs  Rating
# 1654             Subway Surfers  1000000000     4.5
# 336          WhatsApp Messenger  1000000000     4.4
# 3117  Maps - Navigate & Explore  1000000000     4.3
# 340                       Gmail  1000000000     4.3
# 152           Google Play Books  1000000000     3.9
